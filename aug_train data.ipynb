# %% [markdown]
# ## Importing Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("aug_train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df.sample(15)
# Out:
#        enrollee_id      city  city_development_index  gender  \
# 6926          2305   city_21                   0.624     NaN
# 16701         8727  city_103                   0.920  Female
# 4266         17314   city_11                   0.550     NaN
# 9541           204  city_160                   0.920    Male
# 12069        11576  city_103                   0.920     NaN
# 16761         7421   city_16                   0.910    Male
# 12958        13934  city_102                   0.804    Male
# 675          17375  city_157                   0.769    Male
# 16514         1351   city_67                   0.855    Male
# 18524        30436  city_103                   0.920    Male
# 16255        20936  city_103                   0.920    Male
# 7474         22260   city_24                   0.698    Male
# 756           4980  city_114                   0.926    Male
# 9572         19622   city_71                   0.884    Male
# ...

# %%
unique_count=df.nunique()
print(unique_count)
# Out:
# enrollee_id               19158
# city                        123
# city_development_index       93
# gender                        3
# relevent_experience           2
# enrolled_university           3
# education_level               5
# major_discipline              6
# experience                   22
# company_size                  8
# company_type                  6
# last_new_job                  6
# training_hours              241
# target                        2
# dtype: int64

# %%
df["target"]=df["target"].astype('int32')

# %%
df["target"].value_counts()
# Out:
# target
# 0    14381
# 1     4777
# Name: count, dtype: int64

# %%
df["enrolled_university"].value_counts()
# Out:
# enrolled_university
# no_enrollment       13817
# Full time course     3757
# Part time course     1198
# Name: count, dtype: int64

# %% [markdown]
# ### Target Output:
# 1. What experience group is most likely to look for new job?
# 2. which education level is most common among job seeker?
# 3. Do candidates with relevent eperience,have more training Hours?
# 4. what is the average experience in year for each education level?
# 5. which company type has the highest % of people waiting to switch the job?

# %%
# What experience group is most likely to look for new job?
df[["experience","target"]].value_counts()
# Out:
# experience  target
# >20         0         2783
# 5           0         1018
# 4           0          946
# 3           0          876
# 6           0          873
# 10          0          778
# 9           0          767
# 2           0          753
# 7           0          725
# 8           0          607
# 15          0          572
# 11          0          513
# >20         1          503
# 14          0          479
# 3           1          478
# 4           1          457
# 16          0          436
# 5           1          412
# 12          0          402
# 2           1          374
# 6           1          343
# 13          0          322
# 1           0          316
# 7           1          303
# 17          0          285
# <1          0          285
# 19          0          251
# 18          0          237
# <1          1          237
# 1           1          233
# 9           1          213
# 10          1          207
# 8           1          195
# ...

# %% [markdown]
# Using this We can say the >20 year experience group            503

# %%
df[df["target"]==1]["education_level"].value_counts()
# Out:
# education_level
# Graduate          3245
# Masters            935
# High School        394
# Phd                 58
# Primary School      41
# Name: count, dtype: int64

# %% [markdown]
# Graduate                3245

# %%
df[["relevent_experience","training_hours"]].value_counts()
# Out:
# relevent_experience      training_hours
# Has relevent experience  28                237
#                          20                205
#                          22                201
#                          24                199
#                          50                198
#                                           ...
# No relevent experience   272                 1
#                          276                 1
#                          244                 1
#                          330                 1
#                          236                 1
# Name: count, Length: 478, dtype: int64

# %%
df['training_hours'].value_counts()
# Out:
# training_hours
# 28     329
# 12     292
# 18     291
# 22     282
# 50     279
#       ...
# 266      6
# 234      5
# 272      5
# 286      5
# 238      4
# Name: count, Length: 241, dtype: int64

# %%
df['training_hours'].describe()
# Out:
# count    19158.000000
# mean        65.366896
# std         60.058462
# min          1.000000
# 25%         23.000000
# 50%         47.000000
# 75%         88.000000
# max        336.000000
# Name: training_hours, dtype: float64

# %%
for i,j in zip(df['city'].value_counts().index.tolist(), df['city'].value_counts().values.tolist()):
    print(i, '-->', j)
# Out:
# city_103 --> 4355
# city_21 --> 2702
# city_16 --> 1533
# city_114 --> 1336
# city_160 --> 845
# city_136 --> 586
# city_67 --> 431
# city_75 --> 305
# city_102 --> 304
# city_104 --> 301
# city_73 --> 280
# city_100 --> 275
# city_71 --> 266
# city_11 --> 247
# city_90 --> 197
# city_61 --> 197
# city_28 --> 192
# city_23 --> 182
# city_65 --> 175
# city_36 --> 160
# city_173 --> 151
# city_83 --> 143
# city_50 --> 140
# city_116 --> 128
# city_46 --> 128
# city_162 --> 128
# city_138 --> 120
# city_19 --> 119
# city_64 --> 114
# city_45 --> 113
# city_97 --> 104
# city_74 --> 104
# city_57 --> 103
# city_149 --> 102
# city_159 --> 94
# city_99 --> 94
# city_128 --> 92
# city_41 --> 89
# city_10 --> 86
# city_165 --> 82
# city_98 --> 79
# city_105 --> 79
# city_123 --> 79
# city_101 --> 75
# city_40 --> 68
# city_89 --> 67
# city_150 --> 65
# city_145 --> 63
# city_24 --> 62
# city_115 --> 54
# city_142 --> 53
# city_152 --> 51
# city_76 --> 50
# city_158 --> 49
# city_13 --> 48
# ...

# %%
df['city'].unique()
# Out:
# array(['city_103', 'city_40', 'city_21', 'city_115', 'city_162',
#        'city_176', 'city_160', 'city_46', 'city_61', 'city_114',
#        'city_13', 'city_159', 'city_102', 'city_67', 'city_100',
#        'city_16', 'city_71', 'city_104', 'city_64', 'city_101', 'city_83',
#        'city_105', 'city_73', 'city_75', 'city_41', 'city_11', 'city_93',
#        'city_90', 'city_36', 'city_20', 'city_57', 'city_152', 'city_19',
#        'city_65', 'city_74', 'city_173', 'city_136', 'city_98', 'city_97',
#        'city_50', 'city_138', 'city_82', 'city_157', 'city_89',
#        'city_150', 'city_70', 'city_175', 'city_94', 'city_28', 'city_59',
#        'city_165', 'city_145', 'city_142', 'city_26', 'city_12',
#        'city_37', 'city_43', 'city_116', 'city_23', 'city_99', 'city_149',
#        'city_10', 'city_45', 'city_80', 'city_128', 'city_158',
#        'city_123', 'city_7', 'city_72', 'city_106', 'city_143', 'city_78',
# ...

# %%
df[['city', 'num_city']] = df['city'].str.split('_', expand=True)

# %%
df
# Out:
#        enrollee_id  city  city_development_index gender  \
# 0             8949  city                   0.920   Male
# 1            29725  city                   0.776   Male
# 2            11561  city                   0.624    NaN
# 3            33241  city                   0.789    NaN
# 4              666  city                   0.767   Male
# ...            ...   ...                     ...    ...
# 19153         7386  city                   0.878   Male
# 19154        31398  city                   0.920   Male
# 19155        24576  city                   0.920   Male
# 19156         5756  city                   0.802   Male
# 19157        23834  city                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# ...

# %%
df.city.value_counts()
# Out:
# city
# city    19158
# Name: count, dtype: int64

# %%
df['num_city'].unique()
# Out:
# array(['103', '40', '21', '115', '162', '176', '160', '46', '61', '114',
#        '13', '159', '102', '67', '100', '16', '71', '104', '64', '101',
#        '83', '105', '73', '75', '41', '11', '93', '90', '36', '20', '57',
#        '152', '19', '65', '74', '173', '136', '98', '97', '50', '138',
#        '82', '157', '89', '150', '70', '175', '94', '28', '59', '165',
#        '145', '142', '26', '12', '37', '43', '116', '23', '99', '149',
#        '10', '45', '80', '128', '158', '123', '7', '72', '106', '143',
#        '78', '109', '24', '134', '48', '144', '91', '146', '133', '126',
#        '118', '9', '167', '27', '84', '54', '39', '79', '76', '77', '81',
#        '131', '44', '117', '155', '33', '141', '127', '62', '53', '25',
#        '2', '69', '120', '111', '30', '1', '140', '179', '55', '14', '42',
#        '107', '18', '139', '180', '166', '121', '129', '8', '31', '171'],
#       dtype=object)

# %%
df['num_city']=df['num_city'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int32
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# num_city                     0
# dtype: int64

# %%
df.gender.isnull().sum()/19158
# Out:
# 0.23530639941538783

# %%
df.company_type.isnull().sum()/19158
# Out:
# 0.32049274454535964

# %%
df['last_new_job'].value_counts()
# Out:
# last_new_job
# 1        8040
# >4       3290
# 2        2900
# never    2452
# 4        1029
# 3        1024
# Name: count, dtype: int64

# %%
mapping = {
    'never': 0,
    '1': 1,
    '2': 2,
    '3': 3,
    '4': 4,
    '>4': 5
}

# %%
df['last_new_job'] = df['last_new_job'].map(mapping)

# %%
df[df['last_new_job'].isnull()]
# Out:
#        enrollee_id  city  city_development_index gender  \
# 58           13478  city                   0.624    NaN
# 64            9572  city                   0.550    NaN
# 90           19128  city                   0.913   Male
# 135          23947  city                   0.920    NaN
# 180          27708  city                   0.698   Male
# ...            ...   ...                     ...    ...
# 18944         2678  city                   0.924    NaN
# 19043        17966  city                   0.926    NaN
# 19106        18131  city                   0.887   Male
# 19113        11622  city                   0.682    NaN
# 19139         5603  city                   0.624    NaN
#
#            relevent_experience enrolled_university education_level  \
# 58     Has relevent experience    Full time course        Graduate
# 64      No relevent experience    Full time course     High School
# 90      No relevent experience    Full time course        Graduate
# ...

# %%
df[df[['last_new_job','experience']].isnull().any(axis=1)]
# Out:
#        enrollee_id  city  city_development_index gender  \
# 58           13478  city                   0.624    NaN
# 64            9572  city                   0.550    NaN
# 90           19128  city                   0.913   Male
# 135          23947  city                   0.920    NaN
# 180          27708  city                   0.698   Male
# ...            ...   ...                     ...    ...
# 19025        17077  city                   0.698    NaN
# 19043        17966  city                   0.926    NaN
# 19106        18131  city                   0.887   Male
# 19113        11622  city                   0.682    NaN
# 19139         5603  city                   0.624    NaN
#
#            relevent_experience enrolled_university education_level  \
# 58     Has relevent experience    Full time course        Graduate
# 64      No relevent experience    Full time course     High School
# 90      No relevent experience    Full time course        Graduate
# ...

# %%
df[df[['last_new_job','experience']].isnull().all(axis=1)]
# Out:
#        enrollee_id  city  city_development_index  gender  \
# 135          23947  city                   0.920     NaN
# 391          12038  city                   0.698    Male
# 2727         14965  city                   0.920     NaN
# 3086         19706  city                   0.550     NaN
# 3564         15273  city                   0.920     NaN
# 4003         16736  city                   0.920     NaN
# 4336         17123  city                   0.624     NaN
# 5670          7907  city                   0.624     NaN
# 6554         17799  city                   0.920     NaN
# 7608          2978  city                   0.624     NaN
# 7791          5876  city                   0.624     NaN
# 8453          8470  city                   0.920     NaN
# 9793          1435  city                   0.920     NaN
# 9974         16308  city                   0.624  Female
# 9990         15516  city                   0.897    Male
# ...

# %%
print(df.shape)
df = df[~df[['last_new_job', 'experience']].isnull().all(axis=1)]
print(df.shape)
# Out:
# (19158, 15)
# (19134, 15)

# %%
df['experience'].value_counts()
# Out:
# experience
# >20    3286
# 5      1430
# 4      1403
# 3      1354
# 6      1216
# 2      1127
# 7      1028
# 10      985
# 9       980
# 8       802
# 15      686
# 11      664
# 14      586
# 1       549
# <1      522
# 16      508
# 12      494
# 13      399
# 17      342
# 19      304
# 18      280
# 20      148
# Name: count, dtype: int64

# %%
def clean_experience(x):
    if pd.isna(x):
        return x  
    elif x == "<1":
        return 0
    elif x == ">20":
        return 21
    else:
        return int(x)

df['experience'] = df['experience'].apply(clean_experience)
# Out:
# C:\Users\Sudhir\AppData\Local\Temp\ipykernel_13748\2153156421.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['experience'] = df['experience'].apply(clean_experience)

# %%
df['experience'].isnull().sum()
# Out:
# 41

# %%
def exptojob(exp):
    try:
        exp = int(exp)
        if exp < 1:
            return 0
        elif exp >= 8:
            return 5
        else:
            return ((exp + 1) // 2) 
    except:
        return np.nan

# %%
# df['last_new_job']=df['last_new_job'].apply(lambda x: exptojob(x) if x==np.nan else x )

# %%
df.loc[df['last_new_job'].isnull() & df['experience'].notnull(), 'last_new_job'] = df.loc[
    df['last_new_job'].isnull() & df['experience'].notnull(), 'experience'
].apply(exptojob)

# %%
df['last_new_job'].value_counts()
# Out:
# last_new_job
# 1.0    8109
# 5.0    3400
# 2.0    3011
# 0.0    2490
# 3.0    1080
# 4.0    1044
# Name: count, dtype: int64

# %%
df[df['last_new_job'].isnull()]
# Out:
# Empty DataFrame
# Columns: [enrollee_id, city, city_development_index, gender, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, last_new_job, training_hours, target, num_city]
# Index: []

# %%
df['last_new_job'].isnull().sum()
# Out:
# 0

# %%
df['last_new_job'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['last_new_job'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='last_new_job'>

# %%
df[df['experience'].isnull()]
# Out:
#        enrollee_id  city  city_development_index gender  \
# 1589         17642  city                   0.698    NaN
# 2859         24875  city                   0.920    NaN
# 3760         21042  city                   0.920    NaN
# 4207          9306  city                   0.855   Male
# 5043         18350  city                   0.624    NaN
# 6334          8082  city                   0.910    NaN
# 7077         27758  city                   0.920    NaN
# 7083         16915  city                   0.920    NaN
# 7532          3113  city                   0.910   Male
# 7636          2778  city                   0.624    NaN
# 7685         17871  city                   0.698  Other
# 7701         17895  city                   0.624   Male
# 9855          3816  city                   0.836   Male
# 9993         10761  city                   0.624   Male
# 10962        12373  city                   0.920    NaN
# 11536        10645  city                   0.624    NaN
# ...

# %%
def jobtoexp(x):
    if pd.isna(x):
        return x
    elif x==5:
        return x*2 +1
    else:
        return x*2

# %%
df.loc[df['last_new_job'].notnull() & df['experience'].isnull(), 'experience'] = df.loc[
    df['last_new_job'].notnull() & df['experience'].isnull(), 'last_new_job'
].apply(jobtoexp)

# %%
df['experience'].value_counts()
# Out:
# experience
# 21.0    3286
# 5.0     1430
# 4.0     1406
# 3.0     1354
# 6.0     1217
# 2.0     1148
# 7.0     1028
# 10.0     985
# 9.0      980
# 8.0      803
# 15.0     686
# 11.0     671
# 14.0     586
# 1.0      549
# 0.0      530
# 16.0     508
# 12.0     494
# 13.0     399
# 17.0     342
# 19.0     304
# 18.0     280
# 20.0     148
# Name: count, dtype: int64

# %%
df.experience.isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19134 entries, 0 to 19157
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19134 non-null  int64
#  1   city                    19134 non-null  object
#  2   city_development_index  19134 non-null  float64
#  3   gender                  14646 non-null  object
#  4   relevent_experience     19134 non-null  object
#  5   enrolled_university     18749 non-null  object
#  6   education_level         18675 non-null  object
#  7   major_discipline        16327 non-null  object
#  8   experience              19134 non-null  float64
#  9   company_size            13204 non-null  object
#  10  company_type            13009 non-null  object
#  11  last_new_job            19134 non-null  float64
#  12  training_hours          19134 non-null  int64
#  13  target                  19134 non-null  int32
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      13218
# Female     1237
# Other       191
# Name: count, dtype: int64

# %%
df['gender'].isnull().sum()
# Out:
# 4488

# %%
df['gender'] = df['gender'].fillna('Unknown')
# Out:
# C:\Users\Sudhir\AppData\Local\Temp\ipykernel_13748\3009156140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df['gender'].fillna('Unknown')

# %%
df['gender'].isnull().sum()
# Out:
# 0

# %%
pd.crosstab(df['gender'], df['target'], normalize='index') * 100
# Out:
# target           0          1
# gender
# Female   73.645918  26.354082
# Male     77.220457  22.779543
# Other    73.821990  26.178010
# Unknown  69.184492  30.815508

# %%
df['gender'].value_counts()
# Out:
# gender
# Male       13218
# Unknown     4488
# Female      1237
# Other        191
# Name: count, dtype: int64

# %%
# def gen_num(x):
#     if x=='Male':
#         return 1
#     elif x=='Female':
#         return 0
#     elif x=='Other':
#         return -1
#     else:
#         return 2

# %%
# df['gender']=df['gender'].apply(gen_num)

# %%
df=df.drop('city',axis=1)

# %%
df = pd.get_dummies(df, columns=['gender'], drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19134 entries, 0 to 19157
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19134 non-null  int64
#  1   city_development_index  19134 non-null  float64
#  2   relevent_experience     19134 non-null  object
#  3   enrolled_university     18749 non-null  object
#  4   education_level         18675 non-null  object
#  5   major_discipline        16327 non-null  object
#  6   experience              19134 non-null  float64
#  7   company_size            13204 non-null  object
#  8   company_type            13009 non-null  object
#  9   last_new_job            19134 non-null  float64
#  10  training_hours          19134 non-null  int64
#  11  target                  19134 non-null  int32
#  12  num_city                19134 non-null  int32
#  13  gender_Male             19134 non-null  bool
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city_development_index       0
# relevent_experience          0
# enrolled_university        385
# education_level            459
# major_discipline          2807
# experience                   0
# company_size              5930
# company_type              6125
# last_new_job                 0
# training_hours               0
# target                       0
# num_city                     0
# gender_Male                  0
# gender_Other                 0
# gender_Unknown               0
# dtype: int64

# %%
df['relevent_experience'].value_counts()
# Out:
# relevent_experience
# Has relevent experience    13775
# No relevent experience      5359
# Name: count, dtype: int64

# %%
df['relevent_experience']=df['relevent_experience'].apply(lambda x : 1 if x=='Has relevent experience' else 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19134 entries, 0 to 19157
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19134 non-null  int64
#  1   city_development_index  19134 non-null  float64
#  2   relevent_experience     19134 non-null  int64
#  3   enrolled_university     18749 non-null  object
#  4   education_level         18675 non-null  object
#  5   major_discipline        16327 non-null  object
#  6   experience              19134 non-null  float64
#  7   company_size            13204 non-null  object
#  8   company_type            13009 non-null  object
#  9   last_new_job            19134 non-null  float64
#  10  training_hours          19134 non-null  int64
#  11  target                  19134 non-null  int32
#  12  num_city                19134 non-null  int32
#  13  gender_Male             19134 non-null  bool
# ...

# %%
df['enrolled_university'].value_counts()
# Out:
# enrolled_university
# no_enrollment       13802
# Full time course     3750
# Part time course     1197
# Name: count, dtype: int64

# %%
# df['enrolled_university'] = df['enrolled_university'].fillna('other')

# %%
df[df['enrolled_university'].isnull()]
# Out:
#        enrollee_id  city_development_index  relevent_experience  \
# 3            33241                   0.789                    0
# 13            5826                   0.624                    0
# 62           24690                   0.827                    1
# 69            4830                   0.698                    0
# 171          12384                   0.698                    1
# ...            ...                     ...                  ...
# 18958        31115                   0.624                    1
# 18965        26499                   0.920                    1
# 19014         6994                   0.910                    1
# 19109        21334                   0.624                    1
# 19120         7887                   0.624                    0
#
#       enrolled_university education_level major_discipline  experience  \
# 3                     NaN        Graduate  Business Degree         0.0
# ...

# %%
df[df[['enrolled_university','education_level','major_discipline']].isnull().all(axis=1)]
# Out:
#        enrollee_id  city  city_development_index  gender  relevent_experience  \
# 13            5826  city                   0.624       1                    0
# 69            4830  city                   0.698       2                    0
# 171          12384  city                   0.698       2                    1
# 366            604  city                   0.910       1                    0
# 399          23901  city                   0.920       1                    0
# ...            ...   ...                     ...     ...                  ...
# 18142         2669  city                   0.767       2                    0
# 18259        19455  city                   0.698       1                    0
# 18343        15834  city                   0.924       2                    0
# 18608        10451  city                   0.624       2                    0
# 18654        25232  city                   0.910       2                    1
#
# ...

# %%
df = df[~df[['enrolled_university','education_level','major_discipline']].isnull().all(axis=1)]

# %%
df[df[['enrolled_university','education_level']].isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [enrollee_id, city_development_index, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, last_new_job, training_hours, target, num_city, gender_Male, gender_Other, gender_Unknown]
# Index: []

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city_development_index       0
# relevent_experience          0
# enrolled_university        285
# education_level            359
# major_discipline          2707
# experience                   0
# company_size              5840
# company_type              6038
# last_new_job                 0
# training_hours               0
# target                       0
# num_city                     0
# gender_Male                  0
# gender_Other                 0
# gender_Unknown               0
# dtype: int64

# %%
df.enrolled_university.value_counts()
# Out:
# enrolled_university
# no_enrollment       13802
# Full time course     3750
# Part time course     1197
# Name: count, dtype: int64

# %%
df.education_level.value_counts()
# Out:
# education_level
# Graduate          11587
# Masters            4353
# High School        2015
# Phd                 413
# Primary School      307
# Name: count, dtype: int64

# %%
df[df['education_level']=='Primary School']['enrolled_university'].value_counts()
# Out:
# enrolled_university
# no_enrollment       264
# Full time course     32
# Part time course     11
# Name: count, dtype: int64

# %%
df[df['education_level']=='Phd']['enrolled_university'].value_counts()
# Out:
# enrolled_university
# no_enrollment       370
# Full time course     25
# Part time course     12
# Name: count, dtype: int64

# %%
df[df['education_level']=='Phd']['enrolled_university'].isnull().sum()
# Out:
# 0

# %%
df.loc[df['education_level'] == 'Phd', 'enrolled_university'] = \
    df.loc[df['education_level'] == 'Phd', 'enrolled_university'] \
      .fillna(df['enrolled_university'].mode()[0])

# %%
df[df['education_level']=='Primary School']['enrolled_university'].isnull().sum()
# Out:
# 9

# %%
df[df['education_level']=='Primary School']['enrolled_university'].isnull().sum()
# Out:
# 0

# %%
df[df['education_level']=='Primary School']['enrolled_university'].fillna(df['enrolled_university'].mode()[0], inplace=True)
# Out:
# C:\Users\Sudhir\AppData\Local\Temp\ipykernel_13748\3725898297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['education_level']=='Primary School']['enrolled_university'].fillna(df['enrolled_university'].mode()[0], inplace=True)

# %%
df.loc[df['education_level'] == 'Primary School', 'enrolled_university'] = \
    df.loc[df['education_level'] == 'Primary School', 'enrolled_university'] \
      .fillna(df['enrolled_university'].mode()[0])

# %%
df[df['education_level']=='Graduate']['enrolled_university'].value_counts()
# Out:
# enrolled_university
# no_enrollment       8428
# Full time course    2205
# Part time course     784
# Name: count, dtype: int64

# %%
df[df['education_level']=='Graduate']['enrolled_university'].isnull().sum()
# Out:
# 0

# %%
df.loc[df['education_level'] == 'Graduate', 'enrolled_university'] = \
    df.loc[df['education_level'] == 'Graduate', 'enrolled_university'] \
      .fillna("Full time course")

# %%
df.loc[df['education_level'] == 'Masters', 'enrolled_university'] = \
    df.loc[df['education_level'] == 'Masters', 'enrolled_university'] \
      .fillna("Full time course")

# %%
df.loc[df['education_level'] == 'High School', 'enrolled_university'] = \
    df.loc[df['education_level'] == 'High School', 'enrolled_university'] \
      .fillna("Full time course")

# %%
df[df[['enrolled_university','education_level']].isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [enrollee_id, city_development_index, relevent_experience, enrolled_university, education_level, major_discipline, experience, company_size, company_type, last_new_job, training_hours, target, num_city, gender_Male, gender_Other, gender_Unknown]
# Index: []

# %%
df['enrolled_university'].value_counts()
# Out:
# enrolled_university
# no_enrollment       13817
# Full time course     4020
# Part time course     1197
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city_development_index       0
# relevent_experience          0
# enrolled_university          0
# education_level            359
# major_discipline          2707
# experience                   0
# company_size              5840
# company_type              6038
# last_new_job                 0
# training_hours               0
# target                       0
# num_city                     0
# gender_Male                  0
# gender_Other                 0
# gender_Unknown               0
# dtype: int64

# %%
df[df['enrolled_university']=='no_enrollment']['education_level'].isnull().sum()
# Out:
# 270

# %%
df[df['enrolled_university']=='no_enrollment']['education_level'].value_counts()
# Out:
# education_level
# Graduate          8428
# Masters           3540
# High School       1209
# Phd                376
# Primary School     264
# Name: count, dtype: int64

# %%
df[df['enrolled_university']=='Full time course']['education_level'].value_counts()
# Out:
# education_level
# Graduate          2375
# High School        911
# Masters            609
# Primary School      32
# Phd                 25
# Name: count, dtype: int64

# %%
df[df['enrolled_university']=='Full time course']['education_level'].isnull().sum()
# Out:
# 68

# %%
df[df['enrolled_university']=='Part time course']['education_level'].value_counts()
# Out:
# education_level
# Graduate          784
# Masters           204
# High School       165
# Phd                12
# Primary School     11
# Name: count, dtype: int64

# %%
df.loc[df['enrolled_university']=='no_enrollment', 'education_level'] = \
    df.loc[df['enrolled_university']=='no_enrollment', 'education_level'] \
      .fillna("High School")

# %%
df.loc[df['enrolled_university']=='Full time course', 'education_level'] = \
    df.loc[df['enrolled_university']=='Full time course', 'education_level'] \
      .fillna("Masters")

# %%
df.loc[df['enrolled_university']=='Part time course', 'education_level'] = \
    df.loc[df['enrolled_university']=='Part time course', 'education_level'] \
      .fillna("Graduate")

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city_development_index       0
# relevent_experience          0
# enrolled_university          0
# education_level              0
# major_discipline             0
# experience                   0
# company_size              5840
# company_type              6038
# last_new_job                 0
# training_hours               0
# target                       0
# num_city                     0
# gender_Male                  0
# gender_Other                 0
# gender_Unknown               0
# dtype: int64

# %%
df['major_discipline'].value_counts()
# Out:
# major_discipline
# STEM               14475
# Unknown             2707
# Humanities           669
# Other                380
# Business Degree      327
# Arts                 253
# No Major             223
# Name: count, dtype: int64

# %%
df['major_discipline']=df['major_discipline'].fillna('Unknown')

# %%
df.training_hours.value_counts()
# Out:
# training_hours
# 28     328
# 12     291
# 18     288
# 22     279
# 50     278
#       ...
# 228      6
# 272      5
# 286      5
# 238      4
# 234      4
# Name: count, Length: 241, dtype: int64

# %%
df['company_type'].value_counts()
# Out:
# company_type
# Pvt Ltd                9803
# Funded Startup          999
# Public Sector           953
# Early Stage Startup     601
# NGO                     519
# Other                   121
# Name: count, dtype: int64

# %%
df.company_type.isnull().sum()
# Out:
# 6038

# %%
df['company_type'] = df['company_type'].fillna('Other')

# %%
df['company_type'].isnull().sum()
# Out:
# 0

# %%
df.company_size.value_counts()
# Out:
# company_size
# 50-99        3080
# 100-500      2564
# 10000+       2015
# 10/49        1467
# 1000-4999    1326
# <10          1305
# 500-999       875
# 5000-9999     562
# Name: count, dtype: int64

# %%
company_size_map = {
    '<10': 5,
    '10/49': 29.5,
    '50-99': 74.5,
    '100-500': 300,
    '500-999': 750,
    '1000-4999': 3000,
    '5000-9999': 7500,
    '10000+': 15000
}

df['company_size'] = df['company_size'].map(company_size_map)

# %%
df['company_size'].isnull().sum()
# Out:
# 0

# %%
df['company_size'].value_counts()
# Out:
# company_size
# 74.5       8920
# 300.0      2564
# 15000.0    2015
# 29.5       1467
# 3000.0     1326
# 5.0        1305
# 750.0       875
# 7500.0      562
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index        gender  \
# count  19034.000000            19034.000000  19034.000000
# mean   16882.345014                0.829011      1.148524
# std     9623.889338                0.123311      0.561236
# min        1.000000                0.448000     -1.000000
# 25%     8554.250000                0.740000      1.000000
# 50%    16993.500000                0.903000      1.000000
# 75%    25194.750000                0.920000      1.000000
# max    33380.000000                0.949000      2.000000
#
#        relevent_experience    experience  company_size  last_new_job  \
# count         19034.000000  19034.000000  13194.000000  19034.000000
# mean              0.722129     10.104812   3040.981620      2.018914
# std               0.447961      6.774974   5336.053314      1.677910
# min               0.000000      0.000000      5.000000      0.000000
# 25%               0.000000      4.000000     74.500000      1.000000
# ...

# %%
df['company_size'] = df['company_size'].fillna(df['company_size'].mode()[0])

# %%
df['company_size'].describe()
# Out:
# count     19034
# unique        8
# top       50-99
# freq       8920
# Name: company_size, dtype: object

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city_development_index       0
# relevent_experience          0
# enrolled_university          0
# education_level              0
# major_discipline             0
# experience                   0
# company_size                 0
# company_type              6038
# last_new_job                 0
# training_hours               0
# target                       0
# num_city                     0
# gender_Male                  0
# gender_Other                 0
# gender_Unknown               0
# dtype: int64

# %%
df.major_discipline.value_counts()
# Out:
# major_discipline
# STEM               14475
# Humanities           669
# Other                380
# Business Degree      327
# Arts                 253
# No Major             223
# Name: count, dtype: int64

# %%
df['company_type'] = df['company_type'].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19034 entries, 0 to 19157
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19034 non-null  int64
#  1   city_development_index  19034 non-null  float64
#  2   relevent_experience     19034 non-null  int64
#  3   enrolled_university     19034 non-null  object
#  4   education_level         19034 non-null  object
#  5   major_discipline        19034 non-null  object
#  6   experience              19034 non-null  float64
#  7   company_size            19034 non-null  float64
#  8   company_type            19034 non-null  object
#  9   last_new_job            19034 non-null  float64
#  10  training_hours          19034 non-null  int64
#  11  target                  19034 non-null  int32
#  12  num_city                19034 non-null  int32
#  13  gender_Male             19034 non-null  bool
# ...

# %%
df.company_size.value_counts()
# Out:
# company_size
# 74.5       8920
# 300.0      2564
# 15000.0    2015
# 29.5       1467
# 3000.0     1326
# 5.0        1305
# 750.0       875
# 7500.0      562
# Name: count, dtype: int64

# %%
df.company_type.value_counts()
# Out:
# company_type
# Pvt Ltd                9803
# Unknown                6038
# Funded Startup          999
# Public Sector           953
# Early Stage Startup     601
# NGO                     519
# Other                   121
# Name: count, dtype: int64

# %%
df.education_level.value_counts()
# Out:
# education_level
# Graduate          11608
# Masters            4421
# High School        2285
# Phd                 413
# Primary School      307
# Name: count, dtype: int64

# %%
df.enrolled_university.value_counts()
# Out:
# enrolled_university
# no_enrollment       13817
# Full time course     4020
# Part time course     1197
# Name: count, dtype: int64

# %%
df.major_discipline.value_counts()
# Out:
# major_discipline
# STEM               14475
# Unknown             2707
# Humanities           669
# Other                380
# Business Degree      327
# Arts                 253
# No Major             223
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['company_type','education_level','enrolled_university','major_discipline'], drop_first=True)

# %%
df.head()
# Out:
#    enrollee_id  city_development_index  relevent_experience  experience  \
# 0         8949                   0.920                    1        21.0
# 1        29725                   0.776                    0        15.0
# 2        11561                   0.624                    0         5.0
# 3        33241                   0.789                    0         0.0
# 4          666                   0.767                    1        21.0
#
#    company_size  last_new_job  training_hours  target  num_city  gender_Male  \
# 0          74.5           1.0              36       1       103         True
# 1          74.5           5.0              47       0        40         True
# 2          74.5           0.0              83       0        21        False
# 3          74.5           0.0              52       1       115        False
# 4          74.5           4.0               8       0       162         True
#
#    ...  education_level_Phd  education_level_Primary School  \
# ...

# %%
plt.figure(figsize=(40,24))
comtx=df.corr()
sns.heatmap(comtx,annot=True,cmap='coolwarm')
plt.title("CO-Relation Matrix")
# Out:
# Text(0.5, 1.0, 'CO-Relation Matrix')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score

# %%
x=df.drop(columns=['target'])
y=df['target']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
model=LogisticRegression(max_iter=10000)

# %%
model.fit(x_train,y_train,)
# Out:
# C:\Users\Sudhir\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=10000)

# %%
y_pred=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy = ",accuracy)

conf_mat=confusion_matrix(y_test,y_pred)
print("\nConfusion Matrix-\n",conf_mat)

class_report=classification_report(y_test,y_pred)
print("\nClassification Report-\n",class_report)
# Out:
# Accuracy =  0.7541500315192268
#
# Confusion Matrix-
#  [[3296  225]
#  [ 945  293]]
#
# Classification Report-
#                precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85      3521
#            1       0.57      0.24      0.33      1238
#
#     accuracy                           0.75      4759
#    macro avg       0.67      0.59      0.59      4759
# weighted avg       0.72      0.75      0.72      4759
